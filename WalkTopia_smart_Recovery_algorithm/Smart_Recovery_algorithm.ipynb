# %% [markdown]
# #Conten Based Filtering :

# %% [markdown]
# Content-based filtering uses item features to recommend other items similar to what the user likes, based on their previous actions or explicit feedback.

# %% [markdown]
# 1) First we Load our Data.
#
# 2)Now when we are working with any kind of textual data we need to convert it into numbers.
#
# 3) Using various models(more appropriately a transformer) like BERT we can convert this textual data into vectors example  of an image.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4) Now after converting them into vectors we apply SVM algorithm the goal of the SVM algorithm is to create the best line or decision boundary that can segregate n-dimensional space into classes so that we can easily put the new data point in the correct category in the future. This best decision boundary is called a hyperplane.
#
# 5) Now SVM uses cosine similarity measure, so we measure it using this method.

# %% [markdown]
# 6) Now we come to the part where we check our similarity scores.
#
# 7) We take input from the user as per the user's input we give the user a recommendation .

# %% [markdown]
# #Collaborative Filtering :

# %% [markdown]
# Collaborative filtering is a technique that can filter out items that a user might like on the basis of reactions by similar users.
#
# It works by searching a large group of people and finding a smaller set of users with tastes similar to a particular user. It looks at the items they like and combines them to create a ranked list of suggestions.

# %% [markdown]
# 1) We get the data.
#
# 2) Here we will use the other users data to make predictions.
#
# 3) Same as of the previous data preprocess we convert our data into vectors.
#
# 4) Here what we use is that we use SVD algorithm to minimise RMSE(Root Mean square Error) and get great recommendations.
#
# 5)A breif on SVD algorithm , it is a matrix factorization method that generalizes the eigendecomposition of a square matrix (n x n) to any matrix (n x m) .

# %% [markdown]
# 6) Now we fit the data in the model and get recommendations .

# %% [markdown]
# ###Limitations of Collaborative Filtering and Content Based Filtering:

# %% [markdown]
# ### Collaborative Filtering:

# %% [markdown]
# 1) Cannot handle fresh items.
#
# 2)Hard to include side features for query/item

# %% [markdown]
# ##Content Based Filtering

# %% [markdown]
# If the content doesn’t contain enough information to discriminate the items precisely, the recommendation itself risks being imprecise.

# %% [markdown]
# ###Now due to the above Limitations of Collaborative and Content based filtering approach we may get less feasibility, but if we combine this 2 we can have can overcome these limitations.Thus we use Hybrid Recommender algorithm.
